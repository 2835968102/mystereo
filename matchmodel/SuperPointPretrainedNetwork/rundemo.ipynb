# %%
# %run demo_superpoint.py assets/icl_snippet/
# Out:
# Namespace(H=120, W=160, camid=0, conf_thresh=0.015, cuda=False, display_scale=2, img_glob='*.png', input='assets/icl_snippet/', max_length=5, min_length=2, nms_dist=4, nn_thresh=0.7, no_display=False, show_extra=False, skip=1, waitkey=1, weights_path='superpoint_v1.pth', write=False, write_dir='tracker_outputs/')
# ==> Processing Image Directory Input.
# ==> Loading pre-trained network.
# ==> Successfully loaded pre-trained network.
# ==> Running Demo.
# ...

# %%
# %run demo_superpoint.py assets/nyu_snippet.mp4 --cuda --write
# Out:
# Namespace(H=120, W=160, camid=0, conf_thresh=0.015, cuda=True, display_scale=2, img_glob='*.png', input='assets/nyu_snippet.mp4', max_length=5, min_length=2, nms_dist=4, nn_thresh=0.7, no_display=False, show_extra=False, skip=1, waitkey=1, weights_path='superpoint_v1.pth', write=True, write_dir='tracker_outputs/')
# ==> Processing Video Input.
# ==> Loading pre-trained network.
# ==> Successfully loaded pre-trained network.
# ==> Will write outputs to tracker_outputs/
# ==> Running Demo.
# ...
